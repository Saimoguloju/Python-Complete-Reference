# %% [markdown]
# ## Pandas

# %% [markdown]
# ![Python logo](https://miro.medium.com/v2/resize:fit:770/1*pJnfAWcDbz7qnQr7at3jkw.png)

# %%
pip install --upgrade pip
# Out:
# ...
#      ---------------------------------------- 2.1/2.1 MB 555.3 kB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 22.3.1
#     Uninstalling pip-22.3.1:
#       Successfully uninstalled pip-22.3.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pandas
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
import pandas as pd
import numpy as np

# %%
my_Data = np.random.randint(0,101,(4,3))

# %%
my_Data
# Out:
# array([[15, 24, 71],
#        [16, 68,  0],
#        [55, 48, 22],
#        [70, 34, 48]])

# %%
my_index=["india","Japan","Australia","newziland"]

# %%
column=["jan","feb","mar"]

# %%
df=pd.DataFrame(my_Data,index=my_index,columns=column)
df
# Out:
#            jan  feb  mar
# india       15   24   71
# Japan       16   68    0
# Australia   55   48   22
# newziland   70   34   48

# %%
df=pd.read_csv("ds_salaries.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.tail()
# Out:
#      Unnamed: 0  work_year experience_level employment_type      job_title  \
# 602         602       2022               SE              FT  Data Engineer
# 603         603       2022               SE              FT  Data Engineer
# 604         604       2022               SE              FT   Data Analyst
# 605         605       2022               SE              FT   Data Analyst
# 606         606       2022               MI              FT   AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# ...

# %%
df.shape
# Out:
# (607, 12)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=607, step=1)

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df=df.rename(columns={"Unnamed: 0" : "id"})

# %%
df
# Out:
#       id  work_year experience_level employment_type  \
# 0      0       2020               MI              FT
# 1      1       2020               SE              FT
# 2      2       2020               SE              FT
# 3      3       2020               MI              FT
# 4      4       2020               SE              FT
# ..   ...        ...              ...             ...
# 602  602       2022               SE              FT
# 603  603       2022               SE              FT
# 604  604       2022               SE              FT
# 605  605       2022               SE              FT
# 606  606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# 2             Big Data Engineer   85000             GBP         109024
# ...

# %%
df.describe()
# Out:
#                id    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
df.describe().T
# Out:
#                count           mean           std     min      25%       50%  \
# id             607.0     303.000000  1.753701e+02     0.0    151.5     303.0
# work_year      607.0    2021.405272  6.921330e-01  2020.0   2021.0    2022.0
# salary         607.0  324000.062603  1.544357e+06  4000.0  70000.0  115000.0
# salary_in_usd  607.0  112297.869852  7.095726e+04  2859.0  62726.0  101570.0
# remote_ratio   607.0      70.922570  4.070913e+01     0.0     50.0     100.0
#
#                     75%         max
# id                454.5       606.0
# work_year        2022.0      2022.0
# salary         165000.0  30400000.0
# salary_in_usd  150000.0    600000.0
# remote_ratio      100.0       100.0

# %%
df[["job_title"]].head()
# Out:
#                     job_title
# 0              Data Scientist
# 1  Machine Learning Scientist
# 2           Big Data Engineer
# 3        Product Data Analyst
# 4   Machine Learning Engineer

# %%
df[["job_title","salary"]].head()
# Out:
#                     job_title  salary
# 0              Data Scientist   70000
# 1  Machine Learning Scientist  260000
# 2           Big Data Engineer   85000
# 3        Product Data Analyst   20000
# 4   Machine Learning Engineer  150000

# %%
df=df.set_index("id").head()

# %%
df.head(2)
# Out:
#     work_year experience_level employment_type                   job_title  \
# id
# 0        2020               MI              FT              Data Scientist
# 1        2020               SE              FT  Machine Learning Scientist
#
#     salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# id
# 0    70000             EUR          79833                 DE             0
# 1   260000             USD         260000                 JP             0
#
#    company_location company_size
# id
# 0                DE            L
# 1                JP            S

# %%
df=df.reset_index()

# %%
df.head(2)
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 0   0       2020               MI              FT              Data Scientist
# 1   1       2020               SE              FT  Machine Learning Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
#
#   company_location company_size
# 0               DE            L
# 1               JP            S

# %%
df.iloc[0]
# Out:
# id                                 0
# work_year                       2020
# experience_level                  MI
# employment_type                   FT
# job_title             Data Scientist
# salary                         70000
# salary_currency                  EUR
# salary_in_usd                  79833
# employee_residence                DE
# remote_ratio                       0
# company_location                  DE
# company_size                       L
# Name: 0, dtype: object

# %%
df.iloc[1:5]
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 1   1       2020               SE              FT  Machine Learning Scientist
# 2   2       2020               SE              FT           Big Data Engineer
# 3   3       2020               MI              FT        Product Data Analyst
# 4   4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %%
df
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 0   0       2020               MI              FT              Data Scientist
# 1   1       2020               SE              FT  Machine Learning Scientist
# 2   2       2020               SE              FT           Big Data Engineer
# 3   3       2020               MI              FT        Product Data Analyst
# 4   4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# ...

# %%
df[df["salary"]>150000]
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 1   1       2020               SE              FT  Machine Learning Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 1  260000             USD         260000                 JP             0
#
#   company_location company_size
# 1               JP            S

# %%
df[df["employee_residence"]=="US"].count()
# Out:
# id                    1
# work_year             1
# experience_level      1
# employment_type       1
# job_title             1
# salary                1
# salary_currency       1
# salary_in_usd         1
# employee_residence    1
# remote_ratio          1
# company_location      1
# company_size          1
# dtype: int64

# %%
df[(df['salary']>85000) & (df["experience_level"]=="SE")].head()
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 1   1       2020               SE              FT  Machine Learning Scientist
# 4   4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 1  260000             USD         260000                 JP             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 1               JP            S
# 4               US            L

# %%
option=["US","JP"]

# %%
df[df["employee_residence"].isin(option)]
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 1   1       2020               SE              FT  Machine Learning Scientist
# 4   4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 1  260000             USD         260000                 JP             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 1               JP            S
# 4               US            L

# %%
def Last_Two(num):
    return str(num)[-2:]

# %%
Last_Two(9705790015)
# Out:
# '15'

# %%
df["Last_Two"] = df["work_year"].apply(Last_Two)

# %%
df.head(2)
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 0   0       2020               MI              FT              Data Scientist
# 1   1       2020               SE              FT  Machine Learning Scientist
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
#
#   company_location company_size Last_Two
# 0               DE            L       20
# 1               JP            S       20

# %%
def yelp(price):
    if price<10:
        return "$"
    elif price >=10 and price <30:
        return "$$"
    else:
        return "$$$"

# %%
df["Yelp"] = df["salary"].apply(yelp)

# %%
df.head(4)
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 0   0       2020               MI              FT              Data Scientist
# 1   1       2020               SE              FT  Machine Learning Scientist
# 2   2       2020               SE              FT           Big Data Engineer
# 3   3       2020               MI              FT        Product Data Analyst
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
#
#   company_location company_size Last_Two Yelp
# 0               DE            L       20  $$$
# 1               JP            S       20  $$$
# 2               GB            M       20  $$$
# ...

# %%
df.head()
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 0   0       2020               MI              FT              Data Scientist
# 1   1       2020               SE              FT  Machine Learning Scientist
# 2   2       2020               SE              FT           Big Data Engineer
# 3   3       2020               MI              FT        Product Data Analyst
# 4   4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size Last_Two Yelp
# ...

# %%
df.sort_values("salary",ascending=False).head(5)
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 1   1       2020               SE              FT  Machine Learning Scientist
# 4   4       2020               SE              FT   Machine Learning Engineer
# 2   2       2020               SE              FT           Big Data Engineer
# 0   0       2020               MI              FT              Data Scientist
# 3   3       2020               MI              FT        Product Data Analyst
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 1  260000             USD         260000                 JP             0
# 4  150000             USD         150000                 US            50
# 2   85000             GBP         109024                 GB            50
# 0   70000             EUR          79833                 DE             0
# 3   20000             USD          20000                 HN             0
#
#   company_location company_size Last_Two Yelp
# ...

# %%
df.shape
# Out:
# (5, 14)

# %%
df1=pd.read_csv("ds_salaries.csv")

# %%
df1
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# 1    Machine Learning Scientist  260000             USD         260000
# ...

# %%
df=df.rename(columns={"Unnamed: 0":"id"})

# %%
df
# Out:
#    index  id  work_year experience_level employment_type  \
# 0      0   0       2020               MI              FT
# 1      1   1       2020               SE              FT
# 2      2   2       2020               SE              FT
# 3      3   3       2020               MI              FT
# 4      4   4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size Last_Two Yelp
# 0                 DE             0               DE            L       20  $$$
# ...

# %%
df=df.drop('index',axis=1)

# %%
df
# Out:
#    id  work_year experience_level employment_type                   job_title  \
# 0   0       2020               MI              FT              Data Scientist
# 1   1       2020               SE              FT  Machine Learning Scientist
# 2   2       2020               SE              FT           Big Data Engineer
# 3   3       2020               MI              FT        Product Data Analyst
# 4   4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size Last_Two Yelp
# ...

# %%
df['salary'].max()
# Out:
# 260000

# %%
df['salary'].min()
# Out:
# 20000

# %%
df['salary'].sum()
# Out:
# 585000

# %%
df['salary'].mean()
# Out:
# 117000.0

# %%
df['salary'].count()
# Out:
# 5

# %%
df['salary'].mode()
# Out:
# 0     20000
# 1     70000
# 2     85000
# 3    150000
# 4    260000
# Name: salary, dtype: int64

# %%
df['salary'].cumsum()
# Out:
# 0     70000
# 1    330000
# 2    415000
# 3    435000
# 4    585000
# Name: salary, dtype: int64

# %%
print("--------"*5,'THE END',"-------"*5)
# Out:
# ---------------------------------------- THE END -----------------------------------

# %% [markdown]
# Author: [Moguloju_Sai](https://linktr.ee/Moguloju_Sai)
